# %%
import itertools as it
import toolz as tls
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display
from src.experiments import compare_guarantees_experiment
from src.experiments import bargaining_gap_experiment
from src.experiments import total_surplus_experiment
# %matplotlib inline

# %% [markdown]
# # settings

# %%
NUMBER_OF_EXPERIMENTS = 100
PRECISION = 10 # 6 decimal places

# %%
def calc_raios(data, metric_cols, all_cols, group_cols):
    ratios = pd.DataFrame()
    sorted_tuple = tls.compose(tuple, sorted)
    combs = set(map(sorted_tuple, it.product(metric_cols, all_cols)))
    for g1, g2 in combs:
        if g1 == g2:
            continue

        ratios[f'{g1}/{g2}'] = data[g1]/data[g2]

    for gc in group_cols:
        ratios[gc] = data[gc]

    return ratios

def title(title_str, section):
    return

# %% [markdown]
# # 1. Comparing guarantees

# %%
cg_exp = compare_guarantees_experiment.CompareGuaranteeExperiment()
cg_exp.run_and_save(NUMBER_OF_EXPERIMENTS)
cg_exp.columns
# Out:
# {'dc_gr',
#  'familiar_share_gr',
#  'goods_num',
#  'max_min_gr',
#  'min_max_gr',
#  'sb_gr',
#  'utility_type'}

# %%
data = cg_exp.load_experiment()

# %% [markdown]
# ### Normalized mean guarantees values from all experiments for different goods number

# %%
r_data = data.groupby(['utility_type', 'goods_num']).mean()
for idx, i in enumerate(r_data.index.unique('utility_type'), 1):
    gr = r_data.loc[i].plot(figsize=(14, 7), title=f'Fig. 1.{idx}. {i}', style='-')
    [line] = [l for l in gr.get_lines() if l.get_label() == 'familiar_share_gr']
    r_data.loc[i]['familiar_share_gr'].plot(style='o', color=line.get_color())

# %% [markdown]
# ### check that all guarantees lies beetween min_max and max_min guarantees. </br>

# %%
guarantees_columns = [
    'dc_gr',
    'familiar_share_gr',
    'max_min_gr',
    'min_max_gr',
    'sb_gr',
]
data[data['min_max_gr'].round(PRECISION) > data[guarantees_columns].min(axis=1).round(PRECISION)]
# Out:
# Empty DataFrame
# Columns: [dc_gr, familiar_share_gr, max_min_gr, utility_type, min_max_gr, sb_gr, goods_num]
# Index: []

# %%
data[data['max_min_gr'].round(PRECISION) < data[guarantees_columns].max(axis=1).round(PRECISION)]
# Out:
# Empty DataFrame
# Columns: [dc_gr, familiar_share_gr, max_min_gr, utility_type, min_max_gr, sb_gr, goods_num]
# Index: []

# %% [markdown]
# #### Looks like there is no violation for used prcision (10 decimal digits)

# %% [markdown]
# ### Calculate ratios statistics

# %%
ratios = calc_raios(data, ('dc_gr','familiar_share_gr', 'sb_gr'), guarantees_columns, ['utility_type', 'goods_num'])

# %% [markdown]
# #### Ratios mean

# %% [markdown]
# TODO: (x - minMax)/(maxMin - minMax) for all guaratees

# %%
ratios.groupby(['utility_type']).mean().drop(columns=['goods_num'])
# Out:
#               dc_gr/sb_gr  max_min_gr/sb_gr  dc_gr/min_max_gr  \
# utility_type
# cav              1.151730          1.364329          1.228550
# random           0.997845          1.103006          1.128956
# vex              0.825780          1.074114          1.485799
#
#               min_max_gr/sb_gr  familiar_share_gr/min_max_gr  \
# utility_type
# cav                   0.939132                      1.000000
# random                0.892685                      1.150659
# vex                   0.577446                      1.971599
#
#               familiar_share_gr/sb_gr  dc_gr/familiar_share_gr  \
# utility_type
# cav                          0.939132                 1.228550
# random                       1.001375                 0.999084
# vex                          1.074114                 0.771450
#
#               dc_gr/max_min_gr  familiar_share_gr/max_min_gr
# utility_type
# cav                   0.845877                      0.691755
# random                0.905962                      0.915078
# vex                   0.771450                      1.000000

# %% [markdown]
# #### Ratios variance

# %%
ratios.groupby(['utility_type']).var().drop(columns=['goods_num'])
# Out:
#               dc_gr/sb_gr  max_min_gr/sb_gr  dc_gr/min_max_gr  \
# utility_type
# cav              0.001173          0.006414          0.004071
# random           0.007636          0.009814          0.014796
# vex              0.001773          0.003134          0.112136
#
#               min_max_gr/sb_gr  familiar_share_gr/min_max_gr  \
# utility_type
# cav                   0.001486                      0.000000
# random                0.012380                      0.069425
# vex                   0.013490                      0.448544
#
#               familiar_share_gr/sb_gr  dc_gr/familiar_share_gr  \
# utility_type
# cav                          0.001486                 0.004071
# random                       0.001413                 0.011371
# vex                          0.003134                 0.004071
#
#               dc_gr/max_min_gr  familiar_share_gr/max_min_gr
# utility_type
# cav                   0.000992                      0.003969
# random                0.002404                      0.007447
# vex                   0.004071                      0.000000

# %% [markdown]
# # 2. Bargaining gap: agents with same utility types

# %%
def bargaining_gap_plot(data, section):
    r_data = data.groupby(['utility_type', 'mix_param', 'scale_param', 'goods_num']).mean()
    for idx, i in enumerate(r_data.index.droplevel('goods_num').unique(), 1):
        title = str(dict(zip(r_data.index.names[:3], i)))
        title = f'Fig{section}.{idx}. {title}'
        (
            r_data
            .loc[(*i, slice(None))]
            .droplevel(['utility_type', 'mix_param', 'scale_param'])
            .plot(
                figsize=(14, 7), 
                title=title, 
                style='-'
            )
        )

# %%
bg_exp = bargaining_gap_experiment.BargainingGapExperiment()
bg_exp.run_and_save(NUMBER_OF_EXPERIMENTS)
bg_exp.columns
# Out:
# {'dc_gr_sum',
#  'familiar_share_gr_sum',
#  'goods_num',
#  'max',
#  'min',
#  'mix_param',
#  'sb_gr_sum',
#  'scale_param',
#  'utility_type'}

# %%
bg_group_cols = {'utility_type', 'goods_num', 'mix_param', 'scale_param'}
bg_data = bg_exp.load_experiment()

# %% [markdown]
# ### Normalized mean sum guarantees values from all experiments for different goods number and params

# %%
bargaining_gap_plot(bg_data, 2)

# %% [markdown]
# ### check that all guarantees lies beetween min and max guarantees. </br>

# %%
sum_guarantees_columns = [
    'dc_gr_sum',
    'familiar_share_gr_sum',
    'max',
    'min',
    'sb_gr_sum',
]
bg_data[bg_data['max'].round(PRECISION) < bg_data[sum_guarantees_columns].max(axis=1).round(PRECISION)]
# Out:
# Empty DataFrame
# Columns: [scale_param, utility_type, min, dc_gr_sum, max, sb_gr_sum, goods_num, familiar_share_gr_sum, mix_param]
# Index: []

# %%
bg_data[bg_data['min'].round(PRECISION) > bg_data[sum_guarantees_columns].min(axis=1).round(PRECISION)]
# Out:
# Empty DataFrame
# Columns: [scale_param, utility_type, min, dc_gr_sum, max, sb_gr_sum, goods_num, familiar_share_gr_sum, mix_param]
# Index: []

# %% [markdown]
# #### all sum guarantees lies between min and max

# %% [markdown]
# ### Calculate ratios statistics

# %%
bg_ratios = calc_raios(
    bg_data, 
    ('dc_gr_sum','familiar_share_gr_sum', 'sb_gr_sum'), 
    sum_guarantees_columns,
    bg_group_cols
)

# %%
with pd.option_context('display.max_rows', None,):
    display(bg_ratios.groupby(list(bg_group_cols - {'goods_num'})).mean().drop(columns=['goods_num']))
# Out:
#                                     dc_gr_sum/familiar_share_gr_sum  \
# scale_param utility_type mix_param
# 1.0         cav          0.0                               1.225484
#                          0.1                               1.215315
#                          0.5                               1.190298
#                          0.8                               1.208398
#             random       0.0                               0.997780
#                          0.1                               1.000064
#                          0.5                               1.000043
#                          0.8                               1.000215
#             vex          0.0                               0.774516
#                          0.1                               0.784685
#                          0.5                               0.809702
#                          0.8                               0.791602
# 1.5         cav          0.0                               1.228222
#                          0.1                               1.213431
#                          0.5                               1.184824
#                          0.8                               1.204078
#             random       0.0                               0.999508
#                          0.1                               1.000740
#                          0.5                               0.999737
#                          0.8                               0.998916
#             vex          0.0                               0.771778
#                          0.1                               0.786569
#                          0.5                               0.815176
#                          0.8                               0.795922
# 2.0         cav          0.0                               1.226921
#                          0.1                               1.211487
#                          0.5                               1.179714
#                          0.8                               1.200017
#             random       0.0                               0.998588
#                          0.1                               0.999020
#                          0.5                               0.999223
#                          0.8                               1.001504
#             vex          0.0                               0.773079
#                          0.1                               0.788513
#                          0.5                               0.820286
#                          0.8                               0.799983
# 5.0         cav          0.0                               1.230330
#                          0.1                               1.211311
#                          0.5                               1.166661
#                          0.8                               1.193246
#             random       0.0                               0.997656
#                          0.1                               0.999870
#                          0.5                               1.003517
#                          0.8                               1.001124
#             vex          0.0                               0.769670
#                          0.1                               0.788689
#                          0.5                               0.833339
#                          0.8                               0.806754
#
#                                     dc_gr_sum/max  familiar_share_gr_sum/max  \
# scale_param utility_type mix_param
# 1.0         cav          0.0             0.829921                   0.678777
#                          0.1             0.835167                   0.688701
#                          0.5             0.854985                   0.720141
#                          0.8             0.852388                   0.708209
#             random       0.0             0.857183                   0.861537
#                          0.1             0.863953                   0.866425
#                          0.5             0.890832                   0.894841
#                          0.8             0.900240                   0.906604
#             vex          0.0             0.702591                   0.907758
#                          0.1             0.716229                   0.913436
#                          0.5             0.767958                   0.948503
#                          0.8             0.774457                   0.978313
# 1.5         cav          0.0             0.818352                   0.667679
#                          0.1             0.825583                   0.681706
#                          0.5             0.841182                   0.711522
#                          0.8             0.835756                   0.696512
#             random       0.0             0.805127                   0.807565
#                          0.1             0.813285                   0.814409
#                          0.5             0.815978                   0.817847
#                          0.8             0.809336                   0.812526
#             vex          0.0             0.644608                   0.835847
#                          0.1             0.659021                   0.838076
#                          0.5             0.680513                   0.834322
#                          0.8             0.661951                   0.831133
# 2.0         cav          0.0             0.798063                   0.651475
#                          0.1             0.803827                   0.664542
#                          0.5             0.811642                   0.689196
#                          0.8             0.809087                   0.675831
#             random       0.0             0.743392                   0.745563
#                          0.1             0.743867                   0.745251
#                          0.5             1.404563             1.138501
#                          0.8             1.423123             1.150936
#             random       0.0             1.351010             0.997560
#                          0.1             1.349750             0.998461
#                          0.5             1.347564             0.999208
#                          0.8             1.349138             1.000384
#             vex          0.0             1.425976             0.827313
#                          0.1             1.407281             0.831377
#                          0.5             1.388279             0.850606
#                          0.8             1.397390             0.834880
# 5.0         cav          0.0             1.604049             1.151413
#                          0.1             1.614194             1.152964
#                          0.5             1.636753             1.134658
#                          0.8             1.626625             1.149673
#             random       0.0             1.664334             0.997901
#                          0.1             1.664775             0.998828
#                          0.5             1.670029             1.003142
#                          0.8             1.669706             1.000813
#             vex          0.0             1.781481             0.825629
#                          0.1             1.752675             0.830143
#                          0.5             1.718455             0.857090
#                          0.8             1.734802             0.837952

# %%
with pd.option_context('display.max_rows', None,):
    display(bg_ratios.groupby(list(bg_group_cols - {'goods_num'})).var().drop(columns=['goods_num']))
# Out:
#                                     dc_gr_sum/familiar_share_gr_sum  \
# scale_param utility_type mix_param
# 1.0         cav          0.0                               0.002337
#                          0.1                               0.002159
#                          0.5                               0.002171
#                          0.8                               0.003329
#             random       0.0                               0.005358
#                          0.1                               0.005315
#                          0.5                               0.006425
#                          0.8                               0.009599
#             vex          0.0                               0.002337
#                          0.1                               0.002159
#                          0.5                               0.002171
#                          0.8                               0.003329
# 1.5         cav          0.0                               0.002357
#                          0.1                               0.002128
#                          0.5                               0.001940
#                          0.8                               0.003256
#             random       0.0                               0.006139
#                          0.1                               0.005246
#                          0.5                               0.006484
#                          0.8                               0.008711
#             vex          0.0                               0.002357
#                          0.1                               0.002128
#                          0.5                               0.001940
#                          0.8                               0.003256
# 2.0         cav          0.0                               0.002503
#                          0.1                               0.002174
#                          0.5                               0.001956
#                          0.8                               0.002902
#             random       0.0                               0.005539
#                          0.1                               0.005557
#                          0.5                               0.006184
#                          0.8                               0.008379
#             vex          0.0                               0.002503
#                          0.1                               0.002174
#                          0.5                               0.001956
#                          0.8                               0.002902
# 5.0         cav          0.0                               0.003046
#                          0.1                               0.002458
#                          0.5                               0.001948
#                          0.8                               0.002727
#             random       0.0                               0.007884
#                          0.1                               0.007031
#                          0.5                               0.005293
#                          0.8                               0.007650
#             vex          0.0                               0.003046
#                          0.1                               0.002458
#                          0.5                               0.001948
#                          0.8                               0.002727
#
#                                     dc_gr_sum/max  familiar_share_gr_sum/max  \
# scale_param utility_type mix_param
# 1.0         cav          0.0             0.000794                   0.001963
#                          0.1             0.000752                   0.001922
#                          0.5             0.000695                   0.002383
#                          0.8             0.000896                   0.003561
#             random       0.0             0.004630                   0.005020
#                          0.1             0.004263                   0.004767
#                          0.5             0.002410                   0.004387
#                          0.8             0.002390                   0.005991
#             vex          0.0             0.004239                   0.004937
#                          0.1             0.003877                   0.004513
#                          0.5             0.003025                   0.001787
#                          0.8             0.003422                   0.000396
# 1.5         cav          0.0             0.000943                   0.001828
#                          0.1             0.000925                   0.001813
#                          0.5             0.000833                   0.002143
#                          0.8             0.000597                   0.002711
#             random       0.0             0.005608                   0.005100
#                          0.1             0.005174                   0.004705
#                          0.5             0.004186                   0.002705
# 1.5         cav          0.0             0.003883             0.000662
#                          0.1             0.003901             0.000712
#                          0.5             0.004385             0.000694
#                          0.8             0.004832             0.001058
#             random       0.0             0.012202             0.004242
#                          0.1             0.010873             0.003789
#                          0.5             0.005931             0.004876
#                          0.8             0.003366             0.006385
#             vex          0.0             0.017479             0.001040
#                          0.1             0.015491             0.001050
#                          0.5             0.006971             0.000953
#                          0.8             0.003848             0.001563
# 2.0         cav          0.0             0.004194             0.000725
#                          0.1             0.003952             0.000738
#                          0.5             0.003859             0.000771
#                          0.8             0.002494             0.001056
#             random       0.0             0.013133             0.003822
#                          0.1             0.010280             0.004084
#                          0.5             0.004794             0.004712
#                          0.8             0.001654             0.006464
#             vex          0.0             0.018774             0.001126
#                          0.1             0.015055             0.001088
#                          0.5             0.006550             0.001044
#                          0.8             0.003416             0.001482
# 5.0         cav          0.0             0.005075             0.000833
#                          0.1             0.004181             0.000894
#                          0.5             0.001679             0.000858
#                          0.8             0.000903             0.001187
#             random       0.0             0.008899             0.005322
#                          0.1             0.006244             0.005252
#                          0.5             0.002261             0.004366
#                          0.8             0.001349             0.006048
#             vex          0.0             0.011411             0.001300
#                          0.1             0.008001             0.001275
#                          0.5             0.004068             0.001087
#                          0.8             0.003249             0.001563

# %% [markdown]
# # 3. Bargaining gap: agents with different utilities

# %%
bgm_exp = bargaining_gap_experiment.BargainingGapMixedUtilitiesExperiment()
bgm_exp.set_params(
    {
        'scale_param': [1, 5],  # lambda
        'mix_param': [0, 0.8],  # epsilon
    }
)
bgm_exp.run_and_save(NUMBER_OF_EXPERIMENTS)
bgm_exp.columns
# Out:
# {'dc_gr_sum',
#  'familiar_share_gr_sum',
#  'goods_num',
#  'max',
#  'min',
#  'mix_param',
#  'sb_gr_sum',
#  'scale_param',
#  'utility_type'}

# %% [markdown]
# ### Normalized mean sum guarantees values from all experiments for different goods number and params

# %%
bgm_data = bgm_exp.load_experiment()
bargaining_gap_plot(bgm_data, 3)

# %% [markdown]
# # 4. Safe play mean total surplus

# %%
ts_exp = total_surplus_experiment.TotalSurplusExperiment()
ts_exp.set_params(
    {
        'scale_param': [1, 5],  # lambda
        'mix_param': [0, 0.8],  # epsilon
    }
)
ts_exp.run_and_save(NUMBER_OF_EXPERIMENTS)
ts_exp.columns
# Out:
# {'dc1_total_surplus',
#  'dc2_total_surplus',
#  'goods_num',
#  'max',
#  'max_utility',
#  'min',
#  'mix_param',
#  'sb_total_surplus',
#  'scale_param',
#  'utility_type'}

# %%
ts_data = ts_exp.load_experiment()
ts_r_data = ts_data.groupby(['utility_type', 'mix_param', 'scale_param', 'goods_num']).mean()
for idx, i in enumerate(ts_r_data.index.droplevel('goods_num').unique(), 1):
    title = str(dict(zip(ts_r_data.index.names[:3], i)))
    title = f'Fig4.{idx}. {title}'
    (
        ts_r_data
        .loc[(*i, slice(None))]
        .droplevel(['utility_type', 'mix_param', 'scale_param'])
        .plot(
            style=['s-', 'o-', '^-', '.-', 'X-', '--'],
            figsize=(14, 7), 
            title=title, 
        )
    )
